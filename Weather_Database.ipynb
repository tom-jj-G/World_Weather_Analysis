# %% [markdown]
# # Challenge Part 1

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 1500

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['saldanha',
#  'mys shmidta',
#  'butaritari',
#  'ushuaia',
#  'machinga',
#  'new norfolk',
#  'louisbourg',
#  'albany',
#  'quelimane',
#  'hermanus',
#  'busselton',
#  'ust-tsilma',
#  'mawlaik',
#  'port alfred',
#  'lerwick',
#  'xicotencatl',
#  'yerbogachen',
#  'bathsheba',
#  'bredasdorp',
#  'sabha',
#  'hobart',
#  'tsihombe',
#  'katsuura',
#  'samarai',
#  'nyurba',
#  'atuona',
#  'hithadhoo',
#  'cape town',
#  'porbandar',
#  'ponta do sol',
#  'porto novo',
#  'seydi',
#  'allen',
#  'saint george',
#  'mataura',
#  'barrow',
#  'illoqqortoormiut',
#  'brae',
#  'taolanaro',
#  'sentyabrskiy',
#  'louis trichardt',
#  'port elizabeth',
#  'labuhan',
#  'bluff',
#  'tasiilaq',
#  'yellowknife',
#  'dunedin',
#  'rikitea',
#  'aklavik',
#  'laredo',
#  'aksu',
#  'puerto ayora',
#  'panama city',
#  'khatanga',
#  'chokurdakh',
#  'avarua',
#  'beringovskiy',
#  'grand river south east',
#  'malkangiri',
#  'east london',
#  'lieksa',
#  'airai',
#  'san quintin',
# ...

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]        
        # Retrieve the amount of rainfall over the last hour
        try:
            city_rainfall_1h = city_weather["rain"]["1h"]
        except KeyError:
            city_rainfall_1h = 0
            print(f"---/!\ No rainfall during last hour in '{city}'.")
            pass
        # Retrieve the amount of snowfall over the last hour
        try:
            city_snowfall_1h = city_weather["snow"]["1h"]
        except KeyError:
            city_snowfall_1h = 0
            print(f"---/!\ No snowfall during last hour in '{city}'.")        
            pass   
                        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,                          
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rainfall_1h,
                          "Snow (inches)": city_snowfall_1h                                                  
                         })

# If an error is experienced, skip the city.
    except:
        print(f"Data for '{city}' not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# ---/!\ No rainfall during last hour in 'saldanha'.
# ---/!\ No snowfall during last hour in 'saldanha'.
# Data for 'mys shmidta' not found. Skipping...
# ---/!\ No rainfall during last hour in 'butaritari'.
# ---/!\ No snowfall during last hour in 'butaritari'.
# ---/!\ No rainfall during last hour in 'ushuaia'.
# ---/!\ No snowfall during last hour in 'ushuaia'.
# ---/!\ No rainfall during last hour in 'machinga'.
# ---/!\ No snowfall during last hour in 'machinga'.
# ---/!\ No rainfall during last hour in 'new norfolk'.
# ---/!\ No snowfall during last hour in 'new norfolk'.
# Data for 'louisbourg' not found. Skipping...
# ---/!\ No snowfall during last hour in 'albany'.
# ---/!\ No rainfall during last hour in 'quelimane'.
# ---/!\ No snowfall during last hour in 'quelimane'.
# ---/!\ No snowfall during last hour in 'hermanus'.
# ---/!\ No snowfall during last hour in 'busselton'.
# ...

# %%
#length of weather data successfully retrieved
len(city_data)
# Out:
# 554

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Saldanha      ZA -33.01   17.94     59.00        77          33
# 1   Butaritari      KI   3.07  172.79     82.99        75           5
# 2      Ushuaia      AR -54.80  -68.30     37.40        64          75
# 3     Machinga      MW -15.17   35.30     67.24        60          28
# 4  New Norfolk      AU -42.78  147.06     37.99        93          89
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        5.82    scattered clouds            0.0            0.0
# 1       18.03           clear sky            0.0            0.0
# 2       14.99       broken clouds            0.0            0.0
# 3        2.73    scattered clouds            0.0            0.0
# 4        2.57     overcast clouds            0.0            0.0

# %%
# Number of cities with rainfall over the last hour
len(city_data_df.loc[city_data_df["Rain (inches)"]>0])
# Out:
# 57

# %%
# # Number of cities with snowfall over the last hour
len(city_data_df.loc[city_data_df["Snow (inches)"]>0])
# Out:
# 2

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
